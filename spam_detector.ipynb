# %% [markdown]
# # Spam Detector

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Retrieve the Data
#
# The data is located at [https://static.bc-edx.com/ai/ail-v-1-0/m13/challenge/spam-data.csv](https://static.bc-edx.com/ai/ail-v-1-0/m13/challenge/spam-data.csv)
#
# Dataset Source: [UCI Machine Learning Library](https://archive.ics.uci.edu/dataset/94/spambase)
#
# Import the data using Pandas. Display the resulting DataFrame to confirm the import was successful.

# %%
# Import the data
data = pd.read_csv("https://static.bc-edx.com/ai/ail-v-1-0/m13/challenge/spam-data.csv")
data.head()
# Out:
#    word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0            0.00               0.64           0.64           0.0
# 1            0.21               0.28           0.50           0.0
# 2            0.06               0.00           0.71           0.0
# 3            0.00               0.00           0.00           0.0
# 4            0.00               0.00           0.00           0.0
#
#    word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 0           0.32            0.00              0.00                0.00
# 1           0.14            0.28              0.21                0.07
# 2           1.23            0.19              0.19                0.12
# 3           0.63            0.00              0.31                0.63
# 4           0.63            0.00              0.31                0.63
#
#    word_freq_order  word_freq_mail  ...  char_freq_;  char_freq_(  \
# 0             0.00            0.00  ...         0.00        0.000
# ...

# %% [markdown]
# ## Predict Model Performance
#
# You will be creating and comparing two models on this data: a Logistic Regression, and a Random Forests Classifier. Before you create, fit, and score the models, make a prediction as to which model you think will perform better. You do not need to be correct!
#
# Write down your prediction in the designated cells in your Jupyter Notebook, and provide justification for your educated guess.

# %% [markdown]
# I predict that the Random Forests Classifier will perform better than Logistic Regression for this spam detection task. Random Forests can capture complex non-linear relationships between features and handle high-dimensional data well, which is important for text classification problems like spam detection. The dataset contains many frequency-based features that likely have non-linear relationships with the target variable. Additionally, Random Forests are less sensitive to outliers and can model feature interactions automatically, which may be important for detecting spam patterns.

# %% [markdown]
# ## Split the Data into Training and Testing Sets

# %%
# Create the labels set `y` and features DataFrame `X`
y = data['spam']
X = data.drop('spam', axis=1)

# %%
# Check the balance of the labels variable (`y`) by using the `value_counts` function.
y.value_counts()
# Out:
# spam
# 0    2788
# 1    1813
# Name: count, dtype: int64

# %%
# Split the data into X_train, X_test, y_train, y_test
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
X_train.head()
# Out:
#       word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 4576            0.00                0.0           0.00           0.0
# 4401            0.00                0.0           0.00           0.0
# 3707            0.17                0.0           0.17           0.0
# 2362            0.00                0.0           0.00           0.0
# 1537            0.00                0.0           0.00           0.0
#
#       word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 4576           0.00             0.0               0.0                 0.0
# 4401           0.00             0.0               0.0                 0.0
# 3707           0.00             0.0               0.0                 0.0
# 2362           0.00             0.0               0.0                 0.0
# 1537           2.17             0.0               0.0                 0.0
#
#       word_freq_order  word_freq_mail  ...  word_freq_conference  char_freq_;  \
# ...

# %% [markdown]
# ## Create, Fit and Compare Models
#
# Create and compare two different classification models: `LogisticRegression` and `RandomForestClassifier`. Complete the following steps for each model:
#
# 1. Import the model from sklearn.
# 2. Instantiate the model with a `random_state` of 1.
# 3. Fit the model using the training data.
# 4. Use the testing data to make predictions.
# 5. Calculate the accuracy score for the model.

# %%
# Create the Logistic Regression model
from sklearn.linear_model import LogisticRegression

# Instantiate the model
lr_model = LogisticRegression(random_state=1)

# Fit the model
lr_model.fit(X_train, y_train)

# Make predictions
lr_predictions = lr_model.predict(X_test)

# Calculate accuracy score
lr_accuracy = accuracy_score(y_test, lr_predictions)
print(f"Logistic Regression Accuracy: {lr_accuracy}")
# Out:
# Logistic Regression Accuracy: 0.9339704604691572
# c:\Users\peyto\anaconda3\envs\dev\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# Create the Random Forest Classifier model
from sklearn.ensemble import RandomForestClassifier

# Instantiate the model
rf_model = RandomForestClassifier(random_state=1)

# Fit the model
rf_model.fit(X_train, y_train)

# Make predictions
rf_predictions = rf_model.predict(X_test)

# Calculate accuracy score
rf_accuracy = accuracy_score(y_test, rf_predictions)
print(f"Random Forest Accuracy: {rf_accuracy}")
# Out:
# Random Forest Accuracy: 0.9669852302345786

# %% [markdown]
# ## Evaluate the Models
#
# In the designated cells, answer the following questions:
#
# 1. Which model performed better?
# 2. How does that compare to your prediction?

# %% [markdown]
# 1. The Random Forest Classifier performed better with an accuracy of approximately 96.69%, compared to the Logistic Regression model which achieved an accuracy of approximately 93.39%. The Random Forest model outperformed Logistic Regression by about 3.3 percentage points.
#
# 2. This result confirms my prediction that Random Forest would perform better for this spam detection task. As anticipated, the Random Forest model was able to capture more complex patterns and relationships in the data, likely due to its ability to model non-linear relationships and feature interactions. The high-dimensional nature of the dataset with many frequency-based features was well-suited for Random Forest's strengths.
